# %%
#Import Librarairs
import pandas as pd
import numpy as np
import seaborn as sns

import matplotlib
import matplotlib.pyplot as plt
plt.style.use('ggplot')

import warnings
warnings.filterwarnings('ignore')

# %%
#Read the data from source
df = pd.read_csv(r'C:\Users\leevc\Downloads\movies.csv')

# %%
#Look into the data
df
# Out:
#             id                              title  \
# 0       758323                The Pope's Exorcist
# 1       346698                             Barbie
# 2       667538   Transformers: Rise of the Beasts
# 3       640146  Ant-Man and the Wasp: Quantumania
# 4       677179                          Creed III
# ...        ...                                ...
# 722740  912284                              Smile
# 722741  840236              Battling le ténébreux
# 722744  872467            Les p'tits explorateurs
# 722756  548760                Wolves of the North
# 722757  740445              Pandemia en Argentina
#
#                                        genres original_language  popularity  \
# 0                     Horror-Mystery-Thriller                en    5953.227
# 1                    Comedy-Adventure-Fantasy                en    5675.527
# 2            Action-Adventure-Science Fiction                en    5409.104
# ...

# %%
#Check for any missing data
df.isnull().sum()
# Out:
# id                      0
# title                   0
# genres                  0
# original_language       0
# popularity              0
# production_companies    0
# release_date            0
# budget                  0
# revenue                 0
# runtime                 0
# status                  0
# dtype: int64

# %%
#df = df.loc[df['production_companies'] * df['age'] != 0

# %%
df.dropna(inplace=True)

df.isnull().sum()
# Out:
# id                      0
# title                   0
# genres                  0
# original_language       0
# popularity              0
# production_companies    0
# release_date            0
# budget                  0
# revenue                 0
# runtime                 0
# status                  0
# dtype: int64

# %%
#Fill the missing data with 0
#df['genres'] = df['genres'].isnull()
#df['genres'] = df['genres'].fillna('genres')
#df['production_companies'] = df['production_companies'].isnull()
#df['production_companies'] = df['production_companies'].fillna('production_companies')
#df['release_date'] = df['release_date'].isnull()
#df['release_date'] = df['release_date'].fillna('release_date')
#df['runtime'] = df['runtime'].isnull()
#df['runtime'] = df['runtime'].fillna('runtime')
#df.isnull().sum()

# %%
#To check data types of each column
df.dtypes
# Out:
# id                        int64
# title                    object
# genres                   object
# original_language        object
# popularity              float64
# production_companies     object
# release_date             object
# budget                    int64
# revenue                   int64
# runtime                 float64
# status                   object
# dtype: object

# %%
#To arrange the top 10 column starting with the highest revenue value
df.sort_values(by=['revenue'], inplace = False, ascending = False)
# Out:
#             id                         title  \
# 114      19995                        Avatar
# 192     299534             Avengers: Endgame
# 40       76600      Avatar: The Way of Water
# 244        597                       Titanic
# 947     140607  Star Wars: The Force Awakens
# ...        ...                           ...
# 148795  877230         Like a Girl: Season 2
# 148797  303674       Adventure in the Castle
# 148798  409330                    Is It You?
# 148800  949005                    Final Year
# 722757  740445         Pandemia en Argentina
#
#                                           genres original_language  \
# 114     Action-Adventure-Fantasy-Science Fiction                en
# 192             Adventure-Science Fiction-Action                en
# 40              Science Fiction-Adventure-Action                en
# 244                                Drama-Romance                en
# 947     Adventure-Action-Science Fiction-Fantasy                en
# ...

# %%
#To plot using seaborn to see the correlation between revenue and budget
sns.regplot(x="revenue", y="budget", data=df, scatter_kws={'color':'red'}, line_kws={'color': 'blue'})
# Out:
# <Axes: xlabel='revenue', ylabel='budget'>

# %%
#To check on the actual correlation 

df.corr(method='pearson')
# Out:
#                   id  popularity    budget   revenue   runtime
# id          1.000000   -0.026212 -0.121330 -0.088893 -0.247295
# popularity -0.026212    1.000000  0.227847  0.195250  0.042536
# budget     -0.121330    0.227847  1.000000  0.750530  0.082873
# revenue    -0.088893    0.195250  0.750530  1.000000  0.062671
# runtime    -0.247295    0.042536  0.082873  0.062671  1.000000

# %%
#To show the correlation matrix where Budget and Gross has the highest correlation
correlation_matrix = df.corr(method='pearson')
sns.heatmap(correlation_matrix, annot = True)
plt.title("Correlation Matrix for Numeric Features")
plt.xlabel("Movie features")
plt.ylabel("Movie features")
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %%
#Unstack to see in better way
correlation_mat = df.corr(method='pearson')
corr_pairs = correlation_mat.unstack()
corr_pairs
# Out:
# id          id            1.000000
#             popularity   -0.026212
#             budget       -0.121330
#             revenue      -0.088893
#             runtime      -0.247295
# popularity  id           -0.026212
#             popularity    1.000000
#             budget        0.227847
#             revenue       0.195250
#             runtime       0.042536
# budget      id           -0.121330
#             popularity    0.227847
#             budget        1.000000
#             revenue       0.750530
#             runtime       0.082873
# revenue     id           -0.088893
#             popularity    0.195250
#             budget        0.750530
#             revenue       1.000000
#             runtime       0.062671
# runtime     id           -0.247295
#             popularity    0.042536
#             budget        0.082873
#             revenue       0.062671
#             runtime       1.000000
# dtype: float64

# %%
#Sort to see and compare in a quicker way
sorted_pairs = corr_pairs.sort_values()
sorted_pairs
# Out:
# runtime     id           -0.247295
# id          runtime      -0.247295
# budget      id           -0.121330
# id          budget       -0.121330
#             revenue      -0.088893
# revenue     id           -0.088893
# id          popularity   -0.026212
# popularity  id           -0.026212
# runtime     popularity    0.042536
# popularity  runtime       0.042536
# revenue     runtime       0.062671
# runtime     revenue       0.062671
#             budget        0.082873
# budget      runtime       0.082873
# popularity  revenue       0.195250
# revenue     popularity    0.195250
# budget      popularity    0.227847
# popularity  budget        0.227847
# revenue     budget        0.750530
# budget      revenue       0.750530
# id          id            1.000000
# budget      budget        1.000000
# popularity  popularity    1.000000
# revenue     revenue       1.000000
# runtime     runtime       1.000000
# dtype: float64

# %%
#To see correlation > 0.1 only
high_corr = sorted_pairs[(sorted_pairs)>0.1]
high_corr
# Out:
# popularity  revenue       0.195250
# revenue     popularity    0.195250
# budget      popularity    0.227847
# popularity  budget        0.227847
# revenue     budget        0.750530
# budget      revenue       0.750530
# id          id            1.000000
# budget      budget        1.000000
# popularity  popularity    1.000000
# revenue     revenue       1.000000
# runtime     runtime       1.000000
# dtype: float64

# %%
#Budget and Revenue has the highest correlation
